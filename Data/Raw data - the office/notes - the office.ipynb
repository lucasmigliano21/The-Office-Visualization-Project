# %% [markdown]
# # EPISODES

# %%
import pandas as pd

# %%
df=pd.read_csv('the_office_episodes.csv')

# %%
df
# Out:
#      season  episode_num_in_season  episode_num_overall             title  \
# 0         1                      1                    1             Pilot
# 1         1                      2                    2     Diversity Day
# 2         1                      3                    3       Health Care
# 3         1                      4                    4      The Alliance
# 4         1                      5                    5        Basketball
# ..      ...                    ...                  ...               ...
# 196       9                     21                  197  Livin' the Dream
# 197       9                     22                  198          A.A.R.M.
# 198       9                     23                  199          A.A.R.M.
# 199       9                     24                  200            Finale
# 200       9                     25                  201            Finale
#
#          directed_by                                         written_by  \
# ...

# %%
df['year'] = pd.to_datetime(df['original_air_date'])
df['year'] = df['year'].dt.year

# %%
df
# Out:
#      season  episode_num_in_season  episode_num_overall             title  \
# 0         1                      1                    1             Pilot
# 1         1                      2                    2     Diversity Day
# 2         1                      3                    3       Health Care
# 3         1                      4                    4      The Alliance
# 4         1                      5                    5        Basketball
# ..      ...                    ...                  ...               ...
# 196       9                     21                  197  Livin' the Dream
# 197       9                     22                  198          A.A.R.M.
# 198       9                     23                  199          A.A.R.M.
# 199       9                     24                  200            Finale
# 200       9                     25                  201            Finale
#
#          directed_by                                         written_by  \
# ...

# %%
df.to_csv('episodes.csv', index=False)

# %% [markdown]
# # IMDB RATING

# %%
df2=pd.read_csv('the_office_imdb.csv')

# %%
df2
# Out:
#      season  episode_num             title original_air_date  imdb_rating  \
# 0         1            1             Pilot        2005-03-24          7.4
# 1         1            2     Diversity Day        2005-03-29          8.3
# 2         1            3       Health Care        2005-04-05          7.7
# 3         1            4      The Alliance        2005-04-12          8.0
# 4         1            5        Basketball        2005-04-19          8.4
# ..      ...          ...               ...               ...          ...
# 183       9           19     Stairmageddon        2013-04-11          8.0
# 184       9           20    Paper Airplane        2013-04-25          8.0
# 185       9           21  Livin' the Dream        2013-05-02          9.1
# 186       9           22          A.A.R.M.        2013-05-09          9.5
# 187       9           23            Finale        2013-05-16          9.8
#
#      total_votes                                               desc
# ...

# %%
df2 = df2.drop('desc', axis=1)

# %%
df2['year'] = pd.to_datetime(df2['original_air_date'])
df2['year'] = df2['year'].dt.year

# %%
df2
# Out:
#      season  episode_num             title original_air_date  imdb_rating  \
# 0         1            1             Pilot        2005-03-24          7.4
# 1         1            2     Diversity Day        2005-03-29          8.3
# 2         1            3       Health Care        2005-04-05          7.7
# 3         1            4      The Alliance        2005-04-12          8.0
# 4         1            5        Basketball        2005-04-19          8.4
# ..      ...          ...               ...               ...          ...
# 183       9           19     Stairmageddon        2013-04-11          8.0
# 184       9           20    Paper Airplane        2013-04-25          8.0
# 185       9           21  Livin' the Dream        2013-05-02          9.1
# 186       9           22          A.A.R.M.        2013-05-09          9.5
# 187       9           23            Finale        2013-05-16          9.8
#
#      total_votes  year
# 0           7006  2005
# 1           6902  2005
# ...

# %%
df2.to_csv('rating.csv', index=False)

# %% [markdown]
# # LINES

# %%
df3=pd.read_csv('the-office_lines.csv')

# %%
df3
# Out:
#        Unnamed: 0 Character  \
# 0               0   Michael
# 1               1       Jim
# 2               2   Michael
# 3               3       Jim
# 4               4   Michael
# ...           ...       ...
# 58716       61302     Creed
# 58717       61303  Meredith
# 58718       61304   Phyllis
# 58719       61305       Jim
# 58720       61306       Pam
#
#                                                     Line  Season  \
# 0       All right Jim. Your quarterlies look very goo...       1
# 1               Oh, I told you. I couldn’t close it. So…       1
# 2       So you’ve come to the master for guidance? Is...       1
# 3             Actually, you called me in here, but yeah.       1
# 4       All right. Well, let me show you how it’s don...       1
# ...                                                  ...     ...
# 58716   It all seems so very arbitrary. I applied for...       9
# 58717   I just feel lucky that I got a chance to shar...       9
# ...

# %%
df3 = df3.drop(['Unnamed: 0','Line'], axis=1)

# %%
df3=df3.drop_duplicates()

# %%
df3.reset_index(drop=True, inplace=True)

# %%
df3
# Out:
#          Character  Season  Episode_Number
# 0          Michael       1               1
# 1              Jim       1               1
# 2              Pam       1               1
# 3           Dwight       1               1
# 4              Jan       1               1
# ...            ...     ...             ...
# 4060  Carol Stills       9              23
# 4061         Carol       9              23
# 4062         Buyer       9              23
# 4063         Woman       9              23
# 4064  Photographer       9              23
#
# [4065 rows x 3 columns]

# %%
df3.to_csv('char_appearances.csv', index=False)
