# %%
import pandas as pd

# %%
episodes=pd.read_csv('episodes.csv')
rating=pd.read_csv('rating.csv')
appearances=pd.read_csv('char_appearances.csv')

# %%
episodes.head()
# Out:
#    season  episode_num_in_season  episode_num_overall          title  \
# 0       1                      1                    1          Pilot
# 1       1                      2                    2  Diversity Day
# 2       1                      3                    3    Health Care
# 3       1                      4                    4   The Alliance
# 4       1                      5                    5     Basketball
#
#        directed_by                                         written_by  \
# 0       Ken Kwapis  Ricky Gervais & Stephen Merchant and Greg Daniels
# 1       Ken Kwapis                                        B. J. Novak
# 2  Ken Whittingham                                   Paul Lieberstein
# 3     Bryan Gordon                                      Michael Schur
# 4     Greg Daniels                                       Greg Daniels
#
#   original_air_date  prod_code  us_viewers  year
# 0        2005-03-24       1001  11200000.0  2005
# ...

# %%
rating.head()
# Out:
#    season  episode_num          title original_air_date  imdb_rating  \
# 0       1            1          Pilot        2005-03-24          7.4
# 1       1            2  Diversity Day        2005-03-29          8.3
# 2       1            3    Health Care        2005-04-05          7.7
# 3       1            4   The Alliance        2005-04-12          8.0
# 4       1            5     Basketball        2005-04-19          8.4
#
#    total_votes  year
# 0         7006  2005
# 1         6902  2005
# 2         5756  2005
# 3         5579  2005
# 4         6183  2005

# %%
appearances.head()
# Out:
#   Character  Season  Episode_Number
# 0   Michael       1               1
# 1       Jim       1               1
# 2       Pam       1               1
# 3    Dwight       1               1
# 4       Jan       1               1

# %%
appearances.Character.unique()
# Out:
# array(['Michael', 'Jim', 'Pam', 'Dwight', 'Jan', 'Michel', 'Todd Packer',
#        'Phyllis', 'Stanley', 'Oscar', 'Angela', 'Kevin', 'Ryan', 'Man',
#        'Roy', 'Documentary Crew Member', 'Mr. Brown', 'Toby', 'Kelly',
#        'Meredith', 'Travel Agent', 'Man On Phone', 'Everybody', 'Lonny',
#        'Darryl', 'Teammates', 'Michael And Dwight', 'Warehouse Worker',
#        'Madge', 'Worker', 'Packer', 'Katy', 'Guy At Bar', 'Pam And Jim',
#        'Employee', 'Chili’S Employee', 'Waitress', 'Manager',
#        'Kevin’S Computer', 'Warehouse Guy', 'Warehouse Guys', 'Video',
#        'Man In Video', 'Actor', 'Redheaded Actress', 'Mr. O’Malley',
#        'Albiny', 'Pam’S Mom', 'Carol', 'Bill', 'Everyone', 'Crowd',
#        'Song', 'Dwight And Michael', 'Sherri', 'Creed', 'Devon',
#        'Children', 'Kid', 'Vance Refrigeration Worker #1',
#        'Vance Refrigeration Worker #2', 'Hank The Security Guard', 'Ira',
# ...

# %%
appearances['Character']=appearances['Character'].replace({'Dacvid Walalce','Dacvid Wallace','David Wallcve'},'David Wallace')

# %%
appearances.Character.value_counts()
# Out:
# Dwight                  189
# Jim                     186
# Pam                     180
# Kevin                   177
# Angela                  173
#                        ...
# Everyone Watching         1
# Entire Prince Family      1
# Prince Grandfather        1
# Entire Office             1
# Carol Stills              1
# Name: Character, Length: 771, dtype: int64

# %%
appearances['Character']=appearances['Character'].replace({'Dwight.','Dwight [On Phone]','Dwight ','Dwightkschrute'},'Dwight')

# %%
appearances['Character']=appearances['Character'].replace({'Jim ','“Jim”'},'Jim')

# %%
appearances.to_csv('charappearances.csv', index=False)

# %%
appearances.Character.value_counts()
# Out:
# Dwight                  189
# Jim                     186
# Pam                     180
# Kevin                   177
# Angela                  173
#                        ...
# Everyone Watching         1
# Entire Prince Family      1
# Prince Grandfather        1
# Entire Office             1
# Carol Stills              1
# Name: Character, Length: 771, dtype: int64

# %%
appearances.Character.unique()
# Out:
# array(['Michael', 'Jim', 'Pam', 'Dwight', 'Jan', 'Michel', 'Todd Packer',
#        'Phyllis', 'Stanley', 'Oscar', 'Angela', 'Kevin', 'Ryan', 'Man',
#        'Roy', 'Documentary Crew Member', 'Mr. Brown', 'Toby', 'Kelly',
#        'Meredith', 'Travel Agent', 'Man On Phone', 'Everybody', 'Lonny',
#        'Darryl', 'Teammates', 'Michael And Dwight', 'Warehouse Worker',
#        'Madge', 'Worker', 'Packer', 'Katy', 'Guy At Bar', 'Pam And Jim',
#        'Employee', 'Chili’S Employee', 'Waitress', 'Manager',
#        'Kevin’S Computer', 'Warehouse Guy', 'Warehouse Guys', 'Video',
#        'Man In Video', 'Actor', 'Redheaded Actress', 'Mr. O’Malley',
#        'Albiny', 'Pam’S Mom', 'Carol', 'Bill', 'Everyone', 'Crowd',
#        'Song', 'Dwight And Michael', 'Sherri', 'Creed', 'Devon',
#        'Children', 'Kid', 'Vance Refrigeration Worker #1',
#        'Vance Refrigeration Worker #2', 'Hank The Security Guard', 'Ira',
# ...

# %%
appearances=appearances.drop_duplicates()

# %%
appearances.reset_index
# Out:
# <bound method DataFrame.reset_index of          Character  Season  Episode_Number
# 0          Michael       1               1
# 1              Jim       1               1
# 2              Pam       1               1
# 3           Dwight       1               1
# 4              Jan       1               1
# ...            ...     ...             ...
# 4060  Carol Stills       9              23
# 4061         Carol       9              23
# 4062         Buyer       9              23
# 4063         Woman       9              23
# 4064  Photographer       9              23
#
# [4054 rows x 3 columns]>

# %%
appearances.to_csv('characters.csv', index=False)
